# %% [markdown]
# # US Election 2020 Data Analysis

# %%
import pandas as pd

# %%
df = pd.read_csv('US Election 2020.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                52 non-null     object
#  1   Source                               40 non-null     object
#  2   Official/Unofficial                  25 non-null     object
#  3   Total Ballots Counted (Estimate)     52 non-null     object
#  4   Vote for Highest Office (President)  24 non-null     object
#  5   VEP Turnout Rate                     52 non-null     object
#  6   Voting-Eligible Population (VEP)     52 non-null     object
#  7   Voting-Age Population (VAP)          52 non-null     object
#  8   % Non-citizen                        52 non-null     object
#  9   Prison                               52 non-null     object
#  10  Probation                            52 non-null     object
# ...

# %%
df.head()
# Out:
#            State                                             Source  \
# 0  United States                                                NaN
# 1        Alabama  https://www2.alabamavotes.gov/electionnight/st...
# 2         Alaska  https://www.elections.alaska.gov/results/20GEN...
# 3        Arizona       https://results.arizona.vote/#/featured/18/0
# 4       Arkansas  https://results.enr.clarityelections.com/AR/10...
#
#   Official/Unofficial Total Ballots Counted (Estimate)  \
# 0                 NaN                      158,835,004
# 1          Unofficial                        2,306,587
# 2                 NaN                          367,000
# 3                 NaN                        3,400,000
# 4          Unofficial                        1,212,030
#
#   Vote for Highest Office (President) VEP Turnout Rate  \
# 0                                 NaN           66.40%
# 1                           2,297,295           62.60%
# ...

# %% [markdown]
# ## Exploratory data analysis

# %% [markdown]
# Q1. Set heading/caption of dataframe.

# %%
df.style.set_caption('US Election Detail')
# Out:
# <style  type="text/css" >
# ...

# %% [markdown]
# Q2. Show all the states of US.

# %%
states = df['State']

for state in states:
    print(state)
# Out:
# United States
# Alabama
# Alaska
# Arizona
# Arkansas
# California
# Colorado
# Connecticut
# Delaware
# District of Columbia
# Florida
# Georgia
# Hawaii
# Idaho
# Illinois
# Indiana
# Iowa
# Kansas
# Kentucky
# Louisiana
# Maine
# Maryland
# Massachusetts
# Michigan
# Minnesota
# Mississippi
# Missouri
# Montana
# Nebraska
# Nevada
# New Hampshire
# New Jersey
# New Mexico
# New York
# North Carolina
# North Dakota
# Ohio
# Oklahoma
# Oregon
# Pennsylvania
# Rhode Island
# South Carolina
# South Dakota
# Tennessee
# Texas
# Utah
# Vermont
# Virginia
# Washington
# West Virginia
# Wisconsin
# Wyoming

# %% [markdown]
# Q3. Show the records of some states.

# %%
df[df['State'].isin(['Alaska', 'Arkansas', 'New York', 'California'])]
# Out:
#          State                                             Source  \
# 2       Alaska  https://www.elections.alaska.gov/results/20GEN...
# 4     Arkansas  https://results.enr.clarityelections.com/AR/10...
# 5   California                https://electionresults.sos.ca.gov/
# 33    New York                                                NaN
#
#    Official/Unofficial Total Ballots Counted (Estimate)  \
# 2                  NaN                          367,000
# 4           Unofficial                        1,212,030
# 5           Unofficial                       16,800,000
# 33                 NaN                        8,930,000
#
#    Vote for Highest Office (President) VEP Turnout Rate  \
# 2                                  NaN           69.80%
# 4                            1,206,697           55.50%
# 5                                  NaN           64.70%
# 33                                 NaN           65.30%
#
# ...

# %% [markdown]
# Q4. Drop Overseas Eligible column.

# %%
df.drop('Overseas Eligible', axis=1)
# Out:
#                    State                                             Source  \
# 0          United States                                                NaN
# 1                Alabama  https://www2.alabamavotes.gov/electionnight/st...
# 2                 Alaska  https://www.elections.alaska.gov/results/20GEN...
# 3                Arizona       https://results.arizona.vote/#/featured/18/0
# 4               Arkansas  https://results.enr.clarityelections.com/AR/10...
# 5             California                https://electionresults.sos.ca.gov/
# 6               Colorado  https://results.enr.clarityelections.com/CO/10...
# 7            Connecticut                                                NaN
# 8               Delaware  https://elections.delaware.gov/results/html/in...
# 9   District of Columbia  https://electionresults.dcboe.org/election_res...
# 10               Florida  https://floridaelectionwatch.gov/CountyReporti...
# ...

# %% [markdown]
# Q5. Add suffix/prefix to the column name.

# %%
df = df.add_suffix('_election') # after
# df = df.add_prefix('election_') # before

df.head()
# Out:
#   State_election                                    Source_election  \
# 0  United States                                                NaN
# 1        Alabama  https://www2.alabamavotes.gov/electionnight/st...
# 2         Alaska  https://www.elections.alaska.gov/results/20GEN...
# 3        Arizona       https://results.arizona.vote/#/featured/18/0
# 4       Arkansas  https://results.enr.clarityelections.com/AR/10...
#
#   Official/Unofficial_election Total Ballots Counted (Estimate)_election  \
# 0                          NaN                               158,835,004
# 1                   Unofficial                                 2,306,587
# 2                          NaN                                   367,000
# 3                          NaN                                 3,400,000
# 4                   Unofficial                                 1,212,030
#
#   Vote for Highest Office (President)_election VEP Turnout Rate_election  \
# ...
