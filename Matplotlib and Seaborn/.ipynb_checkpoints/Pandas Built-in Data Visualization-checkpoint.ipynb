# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns=list('ABCD'))

# %%
df.head()
# Out:
#           A         B         C         D
# 0 -0.674712  0.780765  0.613799 -0.097875
# 1  0.349250 -0.410353  0.210339  1.882743
# 2  0.242102 -0.650410  1.724158  0.513188
# 3 -1.504253  0.506316  0.980838  0.854131
# 4  0.848324  1.460904 -0.235641  0.096146

# %%
df2 = pd.DataFrame(np.abs(np.random.randn(100, 4)), columns=list('abcd'))

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.324828  0.234685  1.009412  0.554843
# 1  1.674849  1.372765  1.357315  1.299386
# 2  0.837274  0.554400  0.230833  0.487829
# 3  1.703985  0.394387  0.032699  0.951297
# 4  0.208353  1.102417  1.089872  0.411874

# %%
df['A'].hist(bins=30);

# %%
df['A'].plot(kind='hist', bins=30);

# %%
df['A'].plot.hist(bins=30)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot(kind='area', alpha=0.3);

# %%
df2.head(10).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df2.head(10).plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.plot.line(y='C', figsize=(12, 3), lw=2)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='A', y='C', c='B', cmap="coolwarm");

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %%
df.plot.hexbin(x='A', y='B', gridsize=25, cmap='coolwarm');

# %%
df.plot.kde(figsize=(10, 5));
